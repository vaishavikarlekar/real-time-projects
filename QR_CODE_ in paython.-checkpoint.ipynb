# %%
# !pip install qrcode

# %%
import qrcode

# %%
import matplotlib.pyplot as plt

# %%
data = "https://www.instagram.com/p/C2-bfqIoYwNCNQN5I-MYQ0LDbaGo6onVSBcwH40/?igsh=NjR3dGc1ZzhldjR0"
filename = "MY_QR_CODE.png"
image = qrcode.make(data)
image.save("MY_QR-CODE")
plt.imshow(image)

# %% [markdown]
# # what are the qr code and its uses?
#
#
# A quick response(QR) code is  a type of barcode that can be scanned by a digital device
# and which stores information as a seies of pixels in a square-shaped grid.

# %% [markdown]
# # what are the qr code and its uses?
#
# QR codes (or quick Response codes) are  two-dimensional codes that you can scan with a smartphone. the code contains infomtion, usually
#  a site address, and once yu scan it, the code connects you with a resource oh the web.
